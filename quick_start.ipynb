# %% [markdown]
# # Fast Photo Mosaic

# %% [markdown]
# ## Load Image Directories

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from photo_mosaic import *
# %matplotlib inline

types = ["manmade","natural"]

# %% [markdown]
# ## Process Source Images

# %%
# for type in types:
#     data_augmentation(type)

# %% [markdown]
# ## Choose a Target Image

# %%
target_img_pth = os.path.join(COM_pth,"target_2.jpg")
img_target = cv2.imread(target_img_pth)
plt.imshow(img_target[:,:,::-1])
plt.show()

# %% [markdown]
# ## Create Composite Image

# %%
tiles = (16,16)
img_composited = main(target_img_pth,tiles,types)
# img_composite = get_composite(img_target,data_list,tiles,type=types[0])
# Out:
# ...
# making pool:   0%|          | 3/750 [00:00<00:42, 17.70it/s]
# done
# ...
# matching tiles:   0%|          | 0/57 [00:00<?, ?it/s]
# done
# matching tiles: 100%|██████████| 57/57 [00:45<00:00,  1.24it/s]

# %%
cv2.imwrite(COM_pth+"mosaic_"+"target_2.jpg",img_composited)
# Out:
# True

# %% [markdown]
# ### Raw Composition

# %%
# raw composite
plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.imshow(img_composited[:,:,::-1])
plt.subplot(1,2,2)
plt.imshow(img_target[:,:,::-1])
plt.show()
